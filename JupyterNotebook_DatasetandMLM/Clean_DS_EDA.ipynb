# %%
# Load Necessary libraries
import pandas as pd
import numpy as np

# %%
# load cleaned dataset
clean_FHD_predictor_dataset = pd.read_csv("ETL/clean_FHD_predictor_dataset.csv")
clean_FHD_predictor_dataset
# Out:
#       patient_female_id  age  education  current_smoker  cigs_per_day  \
# 0                     0   46          2               0             0
# 1                     1   61          3               1            30
# 2                     2   46          3               1            23
# 3                     3   43          2               0             0
# 4                     4   63          1               0             0
# ...                 ...  ...        ...             ...           ...
# 2029               2029   59          3               1            20
# 2030               2030   63          1               0             0
# 2031               2031   52          1               0             0
# 2032               2032   50          1               0             0
# 2033               2033   52          2               0             0
#
#       bp_meds  prevalent_stroke  prevalent_hyp  diabetes  tot_chol  \
# 0           0                 0              0         0       250
# 1           0                 0              1         0       225
# 2           0                 0              0         0       285
# 3           0                 0              1         0       228
# 4           0                 0              0         0       205
# ...       ...               ...            ...       ...       ...
# 2029        0                 0              0         0       251
# 2030        0                 0              1         0       266
# 2031        0                 0              0         0       265
# 2032        0                 0              1         1       260
# 2033        0                 0              0         0       269
#
#          chol_results  sys_bp  dial_bp                     bp_category    bmi  \
# 0                High   121.0     81.0                        Elevated  28.73
# 1     Borderline high   150.0     95.0  High BP - Hypertenstion Stage2  28.58
# 2                High   130.0     84.0  High BP - Hypertenstion Stage1  23.10
# 3     Borderline high   180.0    110.0             Hypertensive Crisis  30.30
# 4     Borderline high   138.0     71.0  High BP - Hypertenstion Stage1  33.11
# ...               ...     ...      ...                             ...    ...
# 2029             High   125.0     80.0                        Elevated  22.18
# 2030             High   167.0     94.0  High BP - Hypertenstion Stage2  25.23
# 2031             High   137.5     84.5  High BP - Hypertenstion Stage1  26.91
# 2032             High   190.0    130.0             Hypertensive Crisis  43.67
# 2033             High   133.5     83.0  High BP - Hypertenstion Stage1  21.47
#
#      description  heart_rate  glucose       results  ten__year_chd
# 0     Overweight          95       76        normal              0
# 1     Overweight          65      103  pre-diabetes              1
# 2        Normal           85       85        normal              0
# 3          Obese          77       99        normal              0
# 4          Obese          60       85        normal              1
# ...          ...         ...      ...           ...            ...
# 2029     Normal           70       70        normal              0
# 2030  Overweight          95       94        normal              0
# 2031  Overweight          72       86        normal              0
# 2032       Obese          85      260      diabetic              0
# 2033     Normal           80      107  pre-diabetes              0
#
# [2034 rows x 20 columns]

# %%
# Columns
clean_FHD_predictor_dataset.columns
# Out:
# Index(['patient_female_id', 'age', 'education', 'current_smoker',
#        'cigs_per_day', 'bp_meds', 'prevalent_stroke', 'prevalent_hyp',
#        'diabetes', 'tot_chol', 'chol_results', 'sys_bp', 'dial_bp',
#        'bp_category', 'bmi', 'description', 'heart_rate', 'glucose', 'results',
#        'ten__year_chd'],
#       dtype='object')

# %%
# list dataframe data types
clean_FHD_predictor_dataset.dtypes
# Out:
# patient_female_id      int64
# age                    int64
# education              int64
# current_smoker         int64
# cigs_per_day           int64
# bp_meds                int64
# prevalent_stroke       int64
# prevalent_hyp          int64
# diabetes               int64
# tot_chol               int64
# chol_results          object
# sys_bp               float64
# dial_bp              float64
# bp_category           object
# bmi                  float64
# description           object
# heart_rate             int64
# glucose                int64
# results               object
# ten__year_chd          int64
# dtype: object

# %%
#summary of numerical values
FHD_Stat = clean_FHD_predictor_dataset.describe()
FHD_Stat
# Out:
#        patient_female_id      age  education  current_smoker  cigs_per_day  \
# count           2,034.00 2,034.00   2,034.00        2,034.00      2,034.00
# mean            1,016.50    49.74       1.96            0.40          5.50
# std               587.31     8.57       0.97            0.49          8.74
# min                 0.00    32.00       1.00            0.00          0.00
# 25%               508.25    42.00       1.00            0.00          0.00
# 50%             1,016.50    49.00       2.00            0.00          0.00
# 75%             1,524.75    56.00       3.00            1.00         10.00
# max             2,033.00    70.00       4.00            1.00         43.00
#
#        bp_meds  prevalent_stroke  prevalent_hyp  diabetes  tot_chol   sys_bp  \
# count 2,034.00          2,034.00       2,034.00  2,034.00  2,034.00 2,034.00
# mean      0.04              0.01           0.31      0.03    239.64   133.27
# std       0.19              0.08           0.46      0.16     46.17    23.99
# min       0.00              0.00           0.00      0.00    135.00    83.50
# 25%       0.00              0.00           0.00      0.00    206.00   116.00
# 50%       0.00              0.00           0.00      0.00    237.00   128.00
# 75%       0.00              0.00           1.00      0.00    268.00   146.00
# max       1.00              1.00           1.00      1.00    600.00   295.00
#
#        dial_bp      bmi  heart_rate  glucose  ten__year_chd
# count 2,034.00 2,034.00    2,034.00 2,034.00       2,034.00
# mean     82.36    25.52       76.96    81.79           0.12
# std      12.31     4.52       12.12    23.59           0.33
# min      51.00    15.96       46.00    40.00           0.00
# 25%      74.00    22.54       69.00    72.00           0.00
# 50%      81.00    24.72       75.00    78.00           0.00
# 75%      89.00    27.71       85.00    86.00           0.00
# max     142.50    56.80      143.00   394.00           1.00

# %%
# format values float to integer
pd.options.display.float_format = '{:,.0f}'.format
FHD_Stat
# Out:
#        patient_female_id   age  education  current_smoker  cigs_per_day  \
# count              2,034 2,034      2,034           2,034         2,034
# mean               1,016    50          2               0             5
# std                  587     9          1               0             9
# min                    0    32          1               0             0
# 25%                  508    42          1               0             0
# 50%                1,016    49          2               0             0
# 75%                1,525    56          3               1            10
# max                2,033    70          4               1            43
#
#        bp_meds  prevalent_stroke  prevalent_hyp  diabetes  tot_chol  sys_bp  \
# count    2,034             2,034          2,034     2,034     2,034   2,034
# mean         0                 0              0         0       240     133
# std          0                 0              0         0        46      24
# min          0                 0              0         0       135      84
# 25%          0                 0              0         0       206     116
# 50%          0                 0              0         0       237     128
# 75%          0                 0              1         0       268     146
# max          1                 1              1         1       600     295
#
#        dial_bp   bmi  heart_rate  glucose  ten__year_chd
# count    2,034 2,034       2,034    2,034          2,034
# mean        82    26          77       82              0
# std         12     5          12       24              0
# min         51    16          46       40              0
# 25%         74    23          69       72              0
# 50%         81    25          75       78              0
# 75%         89    28          85       86              0
# max        142    57         143      394              1

# %%
#FHD_Stat.to_csv("ETL/FHD_Stat.csv", index = False)
